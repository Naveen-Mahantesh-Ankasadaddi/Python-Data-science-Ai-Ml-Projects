# %% [markdown]
# # Import the Libraries

# %%
import warnings
warnings.filterwarnings('ignore')

from fer import FER
import matplotlib.pyplot as plt 
# %matplotlib inline
from PIL import Image

# %% [markdown]
# # Read the Image

# %%
img=plt.imread(r"C:\Users\Dell\OneDrive\Pictures\Saved Pictures\Sad.jpg")
plt.imshow(img)

# %% [markdown]
# # Detection of the Emotion

# %%
detector=FER(mtcnn=True)

# %% [markdown]
# # Displaying the Image with Emotion

# %%
print(detector.detect_emotions(img))
# Out:
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000193B81288B0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ...

# %%
img1=plt.imread(r"C:\Users\Dell\Downloads\images.jpg")

# %%
detector=FER(mtcnn=True)

# %%
plt.imshow(img1)
print(detector.detect_emotions(img))
# Out:
# [{'box': (94, 28, 73, 73), 'emotions': {'angry': 0.0, 'disgust': 0.0, 'fear': 0.05, 'happy': 0.34, 'sad': 0.32, 'surprise': 0.01, 'neutral': 0.28}}]

# %% [markdown]
# # Top Emotions

# %%
emotions_score=detector.top_emotion(img)
print(emotions_score)
plt.imshow(img)
# Out:
# ('happy', 0.34)

# %%
emotions_score=detector.top_emotion(img1)
print(emotions_score)
plt.imshow(img1)
# Out:
# ('angry', 0.59)

# %%
img5=plt.imread(r"C:\Users\Dell\Downloads\surp.jpg")
detector=FER(mtcnn=True)
emotions_score=detector.top_emotion(img5)
print(emotions_score)
plt.imshow(img5)
# Out:
# ('surprise', 0.98)

# %%
img101=plt.imread(r"C:\Users\Dell\Downloads\images (1).jpg")
detector=FER(mtcnn=True)
emotions_score=detector.top_emotion(img101)
print(emotions_score)
plt.imshow(img101)
# Out:
# ('neutral', 0.81)

# %%
img1001=plt.imread(r"C:\Users\Dell\Downloads\dn.jpg")
detector=FER(mtcnn=True)
emotions_score=detector.top_emotion(img1001)
print(emotions_score)
plt.imshow(img1001)
# Out:
# ('happy', 0.39)
